# %%
from openai import OpenAI
client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key="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",
)

def chat_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content.strip()

# %%
field = 'Computer Science'
resp = chat_gpt(f'Set 10 questions in a tabular format with 2 incorrect answers & 1 correct one. You must mix the answers to be at A, B, or C also the answer meanings should be close and not easy to choose.Column 1: Nos:- 1 to 10\n\nColumn 2: Question:- A random question specified in subject: {field} and no more subjects.\nColumn 3is A: First answer option\n\nColumn 4 is B: Second answer option\n\nColumn 5 is C: Third answer option\n\nColumn 6is ANS: The correct answer(which should be the word which is correct not that letters A,B,C and it should be the value withing that one of choices).\n(Make the answer options one word only). also please dont provide stupid questions\n\x0c')

# %%
print(resp)
# Out:
# | Nos | Question                                             | A          | B           | C         | ANS    |
# |-----|------------------------------------------------------|------------|-------------|-----------|--------|
# | 1   | What does SSL stand for?                             | Securely   | Security    | System    | Security |
# | 2   | What is the purpose of a firewall?                    | Filtering  | Encryption  | Detection | Filtering |
# | 3   | What does ROM stand for?                              | Random     | Read-Only   | Randomly  | Read-Only |
# | 4   | What is the function of an operating system?          | Execution  | Monitoring  | Control   | Control |
# | 5   | Which protocol is used to send emails?                | POP3       | FTP         | IMAP      | SMTP   |
# | 6   | What does CPU stand for?                              | Component  | Processing  | Control   | Processing |
# | 7   | What is the purpose of an index in a database?        | Sorting    | Data Entry  | Retrieval | Retrieval |
# | 8   | What does HTML stand for?                             | Hyperlink  | Hypertext   | Hypermedia| Hypertext |
# | 9   | What is the binary representation of 14?              | 1111       | 1010        | 1100      | 1110   |
# | 10  | What is the difference between TCP and UDP protocols? | Reliable   | Connectionless | Encrypted | Connectionless |

# %%
import pandas as pd
import csv


table_lines = resp.strip().split("\n")[2:]  
table_data   = []

for line in table_lines:
    
    cells = [cell.strip() for cell in line.split('|')[1:-1]]  
    table_data.append(cells)

# Convert list of lists to DataFrame
df = pd.DataFrame(table_data, columns=['Nos', 'Question', 'A', 'B', 'C','ANS'])
df.to_csv(f'{field}.csv',index=False)

# %%
df
# Out:
#   Nos                                           Question          A  \
# 0   1                           What does SSL stand for?   Securely
# 1   2                 What is the purpose of a firewall?  Filtering
# 2   3                           What does ROM stand for?     Random
# 3   4       What is the function of an operating system?  Execution
# 4   5             Which protocol is used to send emails?       POP3
# 5   6                           What does CPU stand for?  Component
# 6   7     What is the purpose of an index in a database?    Sorting
# 7   8                          What does HTML stand for?  Hyperlink
# 8   9           What is the binary representation of 14?       1111
# 9  10  What is the difference between TCP and UDP pro...   Reliable
#
#                 B           C             ANS
# 0        Security      System        Security
# 1      Encryption   Detection       Filtering
# 2       Read-Only    Randomly       Read-Only
# 3      Monitoring     Control         Control
# 4             FTP        IMAP            SMTP
# 5      Processing     Control      Processing
# 6      Data Entry   Retrieval       Retrieval
# 7       Hypertext  Hypermedia       Hypertext
# 8            1010        1100            1110
# 9  Connectionless   Encrypted  Connectionless
